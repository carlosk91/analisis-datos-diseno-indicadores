# %% [markdown]
# # Segmentos y Churn de Hotel VIP
#
# ## Objetivo:
#
# Como dueño de un hotel famoso y con muchas transacciones, registro comercial pendiente a confirmar, deseo saber cuales son mis segmentos de clientes y que segmento es el que mayor ganancia me genera.
#
#
# ## Datos:
#
# - tlacuachitos_vip_customers_data.csv
# - tlacuachitos_express_transactions.csv
#
# ## Actividad 1)
# - Limpia y transforma los datos para realizar segmentos de cliente
# - Genera los segmentos de clientes que consideres prudente
#
# ## Actividad 2)
# - Calcula el LTV a 1 año
# - Evalua el LTV por segmento, cual segmento le conviene a mi negocio y como recomiendas a Marketing usar esta información?

# %% [markdown]
# ## Actividad 1)

# %% [markdown]
# ## Actividad 2)
