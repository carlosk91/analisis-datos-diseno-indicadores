# %% [markdown]
# # Quiz 2: Regresión Lineal y SEM (15 minutos)
#
# **Dataset:** [Customer Personality Analysis (Kaggle)](https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis)
#
# Descarga el archivo `marketing_campaign.csv`. Contiene 2 224 clientes con características sociodemográficas, actividad de compra y gasto por categoría de producto.
#
# ---
# ## Instrucciones generales
# - Trabaja en un Notebook de Jupyter.
# - Usa `pandas`, `statsmodels`, `semopy` y las librerías estándar de Python.
# - Incluye el código y los comentarios necesarios para responder cada inciso.
# - Tiempo total sugerido: **15 minutos** (≈ 7 min por pregunta).
#
# ---
# ## Pregunta 1 (7 min) – Regresión Lineal Multivariable
# **Objetivo:** Identificar los factores que explican el gasto total (`TotalSpend`) de un cliente.
#
# 1. Carga el dataset y crea la variable:
#    ```python
#    spend_cols = ["MntWines","MntFruits","MntMeatProducts","MntFishProducts","MntSweetProducts","MntGoldProds"]
#    df["TotalSpend"] = df[spend_cols].sum(axis=1)
#    ```
# 2. Selecciona como predictores iniciales: `Income`, `Age`, `Kidhome`, `Teenhome`, `Recency`, `NumWebPurchases`, `NumStorePurchases`.
# 3. Ajusta una regresión OLS y aplica **stepwise backward elimination** (p‑value > 0.05) hasta quedarte solo con variables significativas.
# 4. Entrega:
#    - Tabla con los coeficientes finales y sus p‑values.
#    - Interpretación (¿qué variable tiene mayor impacto? ¿qué signo?).
#    - Breve recomendación: ¿qué perfil de cliente conviene impulsar para elevar `TotalSpend`?

# %%
pip install kagglehub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.0/68.0 kB 3.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Pregunta 2 (8 min) – Modelado SEM
# **Objetivo:** Modelar la variable latente de **Fidelidad** del cliente.
#
# 1. Estandariza los indicadores (`StandardScaler`).
# 2. Especifica el modelo SEM en notación lavaan semopy, por ejemplo:
#    ```
#    Fidelidad =~ NumWebPurchases + NumStorePurchases + NumDealsPurchases - Recency
#    ```
# 3. Ajusta el modelo con `semopy.Model` y reporta:
#    - Cargas factoriales de cada indicador.
#    - Coeficiente y p‑value de la relación `Fidelidad → Satisfaccion`.
#    - Métricas de ajuste clave (e.g. CFI o AIC).
# 4. Interpretación ejecutiva: ¿cómo debería la empresa actuar sobre la fidelidad para incrementar la satisfacción y el gasto?

# %%
model_desc = """
# Latent Variables
Fidelidad =~ NumWebPurchases + NumStorePurchases + NumDealsPurchases + Recency
"""
