# %% [markdown]
# # Clase 14: Análisis de Muchas Variables y Correlación en Toma de Decisiones
#
# ## Introducción
# En esta sesión exploraremos cómo realizar análisis de varias variables simultáneamente para entender las relaciones entre ellas. El enfoque principal será la correlación como herramienta para medir la fuerza y dirección de estas relaciones. También analizaremos cómo este conocimiento puede guiar la toma de decisiones en un contexto empresarial.
#
# ---
#
# ## Objetivos de Aprendizaje
# 1. Entender el concepto de correlación y su interpretación en el análisis de datos.
# 2. Aprender a calcular y visualizar matrices de correlación.
# 3. Identificar relaciones significativas entre variables y su relevancia para decisiones empresariales.
# 4. Aplicar el análisis multivariable para generar recomendaciones.
#
# ---
#
# ## Contextualización: Método del Caso (15 minutos)
#
# **Escenario:**
# La empresa "ModaExpress" ha detectado inconsistencias en sus ventas y en el impacto de las promociones entre regiones y categorías de productos. La dirección ha solicitado al equipo de analistas que identifique patrones clave en los datos para optimizar las decisiones sobre promociones y manejo de inventarios.
#
# **Tu rol:**
# Como analistas de datos de "ModaExpress", se espera que uses las herramientas de correlación y análisis multivariable para responder preguntas críticas como:
# - ¿Cómo influyen las promociones en las ventas en cada región?
# - ¿Cuáles categorías de producto responden mejor a los descuentos?
# - ¿Existen factores externos (como el stock disponible o los clientes atendidos) que expliquen las fluctuaciones en las ventas?
#
# **Dinámica inicial:**
# 1. En grupos, reflexiona sobre el problema desde la perspectiva de los directivos:
#    - ¿Cuáles son los mayores retos al interpretar los datos?
#    - ¿Qué decisiones deben tomarse para mejorar el rendimiento general de la empresa?
# 2. Propongan una hipótesis inicial sobre los factores que podrían estar afectando las ventas y discutan cómo podrían validarla con análisis estadísticos.
#
# ---
#
# ## Contenido
#
# ### 1. Introducción a la Correlación (15 minutos)
# La correlación mide:
# - **Fuerza:** Qué tan estrechamente están relacionadas dos variables.
# - **Dirección:** Si una variable aumenta cuando la otra aumenta (correlación positiva) o disminuye (correlación negativa).
#
# #### Ejemplo:
# Supongamos que analizamos el gasto en promociones y las ventas en una empresa:
# - **Correlación positiva:** A mayor gasto en promociones, mayores ventas.
# - **Correlación negativa:** A mayor gasto en promociones, menores ventas (ineficiencia o saturación).
#
# #### Coeficiente de correlación (Pearson):
# - **1.0:** Correlación perfecta positiva.
# - **0.0:** Sin correlación.
# - **-1.0:** Correlación perfecta negativa.
#
# ---
#
# ### 2. Cómo Calcular y Visualizar Correlaciones (20 minutos)
# Podemos usar una **matriz de correlación** para identificar relaciones significativas entre muchas variables.
#
# #### Ejemplo en Python:

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar dataset
data = pd.read_csv("data/modaexpress_ventas.csv")

# Calcular la matriz de correlación
correlation_matrix = data.corr(numeric_only=True)

# Visualizar la matriz
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Matriz de Correlación de Ventas")
plt.show()

# %%
correlation_matrix
# Out:
#                              Ventas (USD)  Gasto en Promociones (USD)  \
# Ventas (USD)                     1.000000                    0.906898
# Gasto en Promociones (USD)       0.906898                    1.000000
# Descuento (%)                    0.155859                    0.011466
# Stock Disponible (Unidades)      0.980151                    0.914254
# Clientes Atendidos               0.976685                    0.911124
#
#                              Descuento (%)  Stock Disponible (Unidades)  \
# Ventas (USD)                      0.155859                     0.980151
# Gasto en Promociones (USD)        0.011466                     0.914254
# Descuento (%)                     1.000000                     0.016110
# Stock Disponible (Unidades)       0.016110                     1.000000
# Clientes Atendidos                0.014762                     0.985049
#
#                              Clientes Atendidos
# Ventas (USD)                           0.976685
# ...

# %% [markdown]
# #### Discusión:
# - Analiza visualmente qué variables tienen las correlaciones más fuertes.
# - Identifica patrones inesperados y posibles sesgos en los datos.
#
# ---

# %% [markdown]
# ### 3. Aplicaciones Prácticas y Decisiones Empresariales (20 minutos)
# #### Caso: ModaExpress
# **Pregunta:** ¿Cómo influyen el gasto en promociones, el stock disponible y los descuentos en las ventas?
#
# 1. Analiza la matriz de correlación para identificar relaciones significativas.
# 2. Preguntas a resolver:
#    - ¿Cuáles variables tienen la mayor correlación con las ventas?
#    - ¿Existen patrones entre las variables que puedan guiar decisiones de inventario o promociones?
#
# #### Ejercicio Guiado:
# - Usando la matriz de correlación, los estudiantes responderán:
#   - ¿En qué región las promociones tienen mayor impacto en las ventas?
#   - ¿Qué categorías de producto son más sensibles a los descuentos?
#
# ---

# %% [markdown]
# Analicemos un scatterplot para ver el impacto de las promociones en las ventas por región

# %%
sns.scatterplot(x=data["Gasto en Promociones (USD)"], y=data["Ventas (USD)"], hue=data["Región"])
# Out:
# <Axes: xlabel='Gasto en Promociones (USD)', ylabel='Ventas (USD)'>

# %% [markdown]
# Ahora, veamos cómo impactan los descuentos en las ventas por categoría de producto

# %%
data['Descuento (%)'].unique()
# Out:
# array([ 5,  0, 10, 15, 20, 30])

# %%
plt.figure(figsize=(8, 4))
sns.barplot(x='Categoría de Producto', y='Ventas (USD)', hue='Descuento (%)', data=data)
plt.title('Comparación de Ventas con y sin Descuento por Categoría')
plt.xticks(rotation=45)
plt.legend(title='Descuento', labels=data['Descuento (%)'].unique(), loc="upper right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4. Análisis Multivariable y Segmentación (30 minutos)
# El análisis multivariable permite entender relaciones complejas considerando varios factores simultáneamente.
#
# #### Ejemplo:
# - La correlación entre las ventas y las promociones podría variar dependiendo de la región o la categoría de producto.
#
# #### Visualización por Segmentos:

# %%
# Relación entre gasto en promociones y ventas, segmentada por región
sns.lmplot(x="Gasto en Promociones (USD)", y="Ventas (USD)", hue="Región", data=data, scatter_kws={'alpha':0.3, 's': 5})
plt.title("Relación Promociones vs Ventas por Región")
plt.show()

# %%
sns.__version__
# Out:
# '0.13.2'

# %%
# Relación entre gasto en promociones y ventas, segmentada por categoría de producto
sns.lmplot(x="Gasto en Promociones (USD)", y="Ventas (USD)", hue="Categoría de Producto", data=data, scatter_kws={'alpha':0.3, 's': 5})
plt.title("Relación Promociones vs Ventas por Categoría de Producto")
plt.show()

# %% [markdown]
# #### Actividad:
# 1. Divide los datos por categoría de producto y analiza si las correlaciones cambian.
# 2. Responde:
#    - ¿Qué categoría de producto tiene la relación más fuerte entre promociones y ventas?
#    - ¿Cómo podría usar la empresa esta información para optimizar sus estrategias?
#
# ---
#
# ### 5. Toma de Decisiones Basada en Análisis Multivariable (15 minutos)
# **Métodos y Estrategias:**
# 1. **Prioriza Acciones:** Basándote en las variables más relevantes para los KPI.
# 2. **Evita Sobreinterpretar:** Identifica relaciones espurias o influencias externas.
# 3. **Aplica Segmentación:** Adapta estrategias a regiones, categorías o periodos específicos.
#
# **Ejercicio Final:**
# - Los estudiantes seleccionan las tres relaciones más significativas de los datos.
# - Proponen una estrategia concreta basada en sus hallazgos.
#
# ---
#
# ## Cierre
# - **Reflexión:**
#   - ¿Cómo ayudó el análisis de correlación a entender mejor los datos?
#   - ¿Qué más podría analizarse con datos adicionales?

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Carlos Kelly
# </footer>
