# %% [markdown]
# ## **Sesión 14: Elaboración de Presentaciones Ejecutivas**
#
# ### **Objetivo**
# - Estructurar y diseñar presentaciones ejecutivas efectivas.
# - Identificar las diferencias clave en la manera de presentar según la audiencia (C-level, directores, gerentes).
# - Comprender el uso de herramientas y principios de diseño adecuados para presentaciones ejecutivas.
#
# ---

# %% [markdown]
# ### **1. Introducción a las Presentaciones Ejecutivas (15 minutos)**
#
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://cdn-icons-png.flaticon.com/512/609/609046.png" width="120" />
#   </div>
#   <div style="flex: 6;">
#     <strong>1. Definición:</strong><br>
#     Resumen claro, estructurado y visualmente atractivo de un análisis o propuesta, que tiene como objetivo comunicar los hallazgos clave y las recomendaciones de manera rápida y eficaz a una audiencia de alto nivel (gerentes, directores, C-level).
#     <br> <br>
#     <ins><strong>Objetivo:</strong></ins> Tomar decisiones estratégicas y operativas con base en los resultados presentados.
#   </div>
# </div>
#
# **2. Características de una buena presentación ejecutiva:**
#
# - **Claridad**: Ser directo y evitar información innecesaria.<br>
# - **Concisión**: Resumir lo esencial para poder tomar una decisión (dependiendo del tema y el objetivo de la presentación).<br>
# - **Visualización:** Usar gráficos y datos para hacer la información comprensible de forma rápida.<br>
# - **Enfoque en los resultados y las recomendaciones:** La audiencia debe salir con una idea clara de lo que se espera que hagan después de la presentación.
#
# **3. Tipos de presentaciones ejecutivas:**
#
# <div style="display: flex; justify-content: space-around; align-items: center;">
#   <div style="text-align: center; margin-right: 30px;">
#     <p><strong>Informativas</strong></p>
#     <img src="https://cdn-icons-png.flaticon.com/512/10580/10580605.png" alt="Imagen 1" style="width: 100px;" />
#     <p>Para presentar hechos y resultados sin esperar una respuesta inmediata.</p>
#   </div>
#   <div style="text-align: center;">
#     <p><strong>Persuasivas</strong></p>
#     <img src="https://cdn-icons-png.flaticon.com/512/2572/2572160.png" alt="Imagen 2" style="width: 100px;" />
#     <p>Para convencer a la audiencia de tomar una decisión o adoptar una estrategia.</p>
#   </div>
#   <div style="text-align: center;">
#     <p><strong>Decisionales</strong></p>
#     <img src="https://cdn-icons-png.flaticon.com/512/3079/3079018.png" alt="Imagen 3" style="width: 100px;" />
#     <p>Cuando se presentan opciones y se pide a la audiencia tomar una decisión.</p>
#   </div>
# </div>
#
# ---

# %% [markdown]
# ### **2. La Importancia de la Identificación de la Audiencia (15 minutos)**
#
# La forma de presentar los datos y el nivel de detalle depende directamente del perfil de tu audiencia.
#
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://img.freepik.com/vector-premium/diseno-personajes-hombre-mujer-ceo_73842-503.jpg" width="130" />
#   </div>
#   <div style="flex: 6;">
#     <strong>1. C-level (CEO, CFO, etc.):</strong><br>
#     Los ejecutivos de nivel C están principalmente interesados en la visión global y en cómo los resultados impactan en la organización a largo plazo. Les importa la toma de decisiones estratégicas.
#     <br>
#     <li><ins><strong>Cómo presentar:</strong></ins> Enfoque en los resultados clave y sus implicaciones estratégicas. Usa datos claros y con un enfoque de alto nivel.</li>
#     <li><ins><strong>Consejos:</strong></ins> Evita detalles operacionales. Utiliza un storytelling claro, con datos clave y visuales efectivos.</li>
#   </div>
# </div>
#
# <br>
# <br>
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://img.freepik.com/vector-premium/ilustracion-vector-equipo-negocios-profesional_760443-703.jpg" width="150" />
#   </div>
#   <div style="flex: 6;">
#     <strong>2. Directores:</strong><br>
#     Los directores se encuentran en una posición más operativa y están interesados en cómo las decisiones estratégicas se implementan a nivel departamental. Se preocupan por la ejecución táctica de las decisiones.
#     <br>
#     <li><ins><strong>Cómo presentar:</strong></ins> Muestra cómo los datos se alinean con los objetivos de la empresa, pero incluye detalles operacionales más específicos.</li>
#     <li><ins><strong>Consejos:</strong></ins> Combina datos estratégicos con ejemplos prácticos. Usa gráficos y tablas para destacar el progreso hacia los objetivos.</li>
#   </div>
# </div>
#
# <br>
# <br>
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://i.pinimg.com/736x/87/d7/4e/87d74ed9b8671878be51a5ab93cfbb6b.jpg" width="150" />
#   </div>
#   <div style="flex: 6;">
#     <strong>3. Gerentes:</strong><br>
#     Los gerentes están más enfocados en la ejecución diaria, las tareas y la supervisión de equipos. Les interesa conocer cómo los proyectos afectarán las operaciones cotidianas y qué cambios pueden esperar en su trabajo y en el de sus equipos.
#     <br>
#     <li><ins><strong>Cómo presentar:</strong></ins> Proporciona detalles sobre la ejecución, cómo las decisiones se implementarán y los resultados medibles en su área.</li>
#     <li><ins><strong>Consejos:</strong></ins> Presenta datos operacionales detallados, pero mantén un enfoque práctico y enfocado en la implementación.</li>
#   </div>
# </div>
#
# ---

# %% [markdown]
# ### **Caso Práctico: Tipos de Audiencia (15 min)**
#
# ### **Contexto del Caso:**
#
# La empresa **Tech Innovations**, está a punto de lanzar su **nuevo software ProjectMaster 360 para gestión de proyectos**, dirigido a pequeñas y medianas empresas (PYMES). Este software está diseñado para ayudar a las PYMES a organizar, coordinar y gestionar proyectos de manera más eficiente, con un enfoque en la colaboración en tiempo real, seguimiento de tareas, y la integración con herramientas populares como Slack, Google Drive y Microsoft Teams.
#
# <center>
#  <img src="https://www.servnet.mx/hs-fs/hubfs/Blog/Blog_Articulos/Blog_Art%C3%ADculos/Blog_Articulos_2023_Abril/Blog_Articulos_2023_Abril_Art26_SEGI/Mecanismos-detectivos-en-seguridad-informatica.png?width=900&height=500&name=Mecanismos-detectivos-en-seguridad-informatica.png"  width="300" />
# </center>
#
# Datos relevantes para la presentación:
#
# - **Precio de suscripción:**
#   - **Mensual:** $25 por usuario
#   - **Anual:** $240 por usuario (descuento del 20%)
# - **Mercado Objetivo:** PYMES con entre 10 y 200 empleados.
# - **Proyección de ventas:**
#   - Año 1: 1,000 clientes
#   - Año 2: 2,500 clientes
#   - Año 3: 5,000 clientes
# - **Costos de implementación:**
#   - **Desarrollo inicial:** $500,000
#   - **Soporte y mantenimiento anual:** $100,000
# - **Proyección de ingresos:**
#   - **Año 1:** $1,000,000
#   - **Año 2:** $6,000,000
#   - **Año 3:** $12,000,000
# - **Crecimiento esperado de clientes:** 150% anual
# - **Competencia:** Existen 5 competidores principales en el mercado con precios similares.
#
# ---
#
# ### **Instrucciones para los Estudiantes:**
#
# 1. **Trabajo en equipo (3 equipos)**. Cada grupo representará una de las tres audiencias:
#    - **C-level (CEO, CFO, etc.)**
#    - **Directores**
#    - **Gerentes**
#
# 2. **Cada grupo debe decidir:**
#    - **Qué datos son más relevantes** para cada tipo de audiencia.
#    - **Cómo presentar los datos** de manera que resuenen con las prioridades de la audiencia (e.g., ROI, implementación, productividad).
#    - **Qué nivel de detalle es necesario** (e.g., proyecciones de ingresos y crecimiento para C-level, detalles operativos y de implementación para gerentes).
#
# 3. **Tiempo de trabajo:** Los estudiantes tendrán 10 minutos para analizar los datos proporcionados y estructurar la presentación adaptada a la audiencia.
#
# 4. **Presentación final:** Después de 10 minutos, cada grupo tendrá 2 minutos para compartir sus conclusiones con la clase y explicar cómo adaptaron la presentación para su audiencia.
#
# ---

# %% [markdown]
# **1. C-level (CEO, CFO, etc.)**
#
# - **Intereses clave:**
#   - .
#   - .
#   - .
#
# - **Datos Relevantes a Presentar:**
#   - .
#   - .
#   - .
# - **Formato de Presentación:**
#   - .
#   - .
# - **Visual**
#   - .
#   - .
# ---

# %% [markdown]
# **2. Directores**
#
# - **Intereses clave:**
#   - .
#   - .
#   - .
#
# - **Datos Relevantes a Presentar:**
#   - .
#   - .
#   - .
# - **Formato de Presentación:**
#   - .
#   - .
# - **Visual**
#   -  .
#   -  .
# ---

# %% [markdown]
# **3. Gerentes**
#
# - **Intereses clave:**
#   - .
#   - .
#   - .
#
# - **Datos Relevantes a Presentar:**
#   - .
#   - .
#   - .
# - **Formato de Presentación:**
#   - .
#   - .
# - **Visual**
#   - .
#   - .
# ---

# %% [markdown]
# ### **3. Cómo Crear una Presentación Ejecutiva (30 minutos)**
#
# #### **Estructura básica de la presentación:**
#
# - **Introducción**: Contexto y objetivos de la presentación.
# - **Desarrollo**: Principales hallazgos, análisis, y visualización de datos.
# - **Conclusión**: Resumen, recomendaciones, y próximos pasos.
#
# #### **La importancia del storytelling en una presentación ejecutiva:**
#
# ##### **¿Qué es el storytelling?**
# El storytelling es la técnica de contar una historia para conectar emocionalmente con tu audiencia. En presentaciones ejecutivas, ayuda a transmitir datos complejos de forma que se comprendan y sean impactantes.
#
# <center>
#  <img src="https://www.blastanalytics.com/wp-content/uploads/2020/10/data-storytelling-training-elements.png"  width="300" />
# </center>
#
# ##### **Cómo integrar storytelling:**
# 1. **Comienza con una narrativa clara**: Introduce un reto o situación que necesita una solución (diagnóstico).
# 2. **Presenta los datos como personajes**: Los datos deben ser presentados como elementos que respaldan la solución propuesta, no como números aislados.
# 3. **Cierra con una llamada a la acción**: Termina con una conclusión clara y concreta que resuma las decisiones que la audiencia debe tomar.
#
#  **Diseño visual en presentaciones ejecutivas:**
# - Uso de colores, tipografías y gráficas para reforzar el mensaje.
# - Eliminar elementos visuales innecesarios y centrarse en lo que realmente importa.
#
# #### **Ejemplo: Análisis sobre la Caída de Ventas en UrbanChic**:
#
# Imagina que eres un analista de datos de la empresa **UrbanChic**, dedicada a la fabricación y venta de prendas textiles, y te han solicitado presentar un análisis sobre la caída de las ventas.
#
# <center>
#   <img src="https://img.freepik.com/vector-gratis/fondo-tienda-ropa-moda_1308-53117.jpg" width="270" />
# </center>
#
# 1. **Inicio (Contexto):**
# Hace seis meses, **UrbanChic** experimentaba un crecimiento sostenido de ventas. Todo indicaba que estábamos en el camino correcto, pero algo cambió…
# *(Incluir gráfica de tendencia, comparativas de ventas, y KPIs relevantes para ilustrar la situación)*
#
# 2. **Conflicto (Problema):**
# En el último trimestre, nuestras ventas cayeron un **15%**. Este descenso no solo es preocupante por su magnitud, sino que también pone en riesgo nuestra **participación de mercado**. Es crucial entender las causas de esta caída y tomar medidas rápidas para revertir la tendencia.
#
# 3. **Desarrollo (Análisis):**
# Se realizó un análisis exhaustivo de los siguientes aspectos:
#
# - **Variación de ventas por categoría de productos:** Se observó que todas las categorías de productos experimentaron el mismo decremento en ventas.
# - **Variación de ventas en las 4 sucursales de UrbanChic:** Sólo una sucursal mostró crecimiento, mientras que las demás tuvieron una caída significativa en sus ventas.
# - **Listado de campañas realizadas:** Se documentaron todas las campañas lanzadas y las fechas en las que se realizaron, para evaluar su impacto.
# - **Impacto de ofertas lanzadas en los últimos 2 años:** Se revisaron las ofertas aplicadas, con el fin de ver cómo han influido en las ventas.
# - **Análisis de mercado:** Estudiamos las estrategias de la competencia para comprender su impacto en el mercado y nuestras ventas.
#
# Trabajando estrechamente con el equipo de marketing, descubrimos que el principal problema radica en la **falta de innovación en nuestras ofertas**. La sucursal que muestra crecimiento ha implementado una nueva oferta, mientras que el resto de las sucursales mantiene las mismas promociones que el año pasado, lo que ha afectado negativamente su desempeño.
#
# 4. **Resolución (Recomendaciones):**
# Nuestra recomendación es **implementar una nueva estructura de promociones**, similar a la que la sucursal en crecimiento ha adoptado. Con base en las proyecciones de impacto, creemos que esta estrategia podría ayudarnos a recuperar un **10% de la cuota de mercado** en los próximos seis meses.
#
# ---

# %% [markdown]
# ### **4. Do’s y Don’ts en una Presentación Ejecutiva (10 minutos)**
#
# #### Do’s:
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://cdn-icons-png.flaticon.com/512/5610/5610944.png" width="100" />
#   </div>
#   <div style="flex: 6;">
#     <li><ins><strong>Sé claro y directo:</strong></ins> No te pierdas en detalles. El mensaje debe ser sencillo y fácil de seguir.</li>
#     <li><ins><strong>Utiliza datos relevantes:</strong></ins> Los datos deben apoyar tus puntos principales y ser fáciles de interpretar.</li>
#     <li><ins><strong>Usa gráficos simples y efectivos:</strong></ins> Asegúrate de que sean comprensibles y no sobrecarguen de información.</li>
#     <li><ins><strong>Prepara respuestas a preguntas:</strong></ins> Anticipa posibles dudas y prepárate para responderlas de manera concisa.</li>
#   </div>
# </div>
#
# #### Don’ts:
# <div style="display: flex; align-items;">
#   <div style="flex: 1.2;">
#     <img src="https://cdn-icons-png.flaticon.com/512/458/458594.png" width="100" />
#   </div>
#   <div style="flex: 6;">
#     <li><ins><strong>No uses demasiados textos o datos:</strong></ins> El exceso de información puede distraer y dificultar la toma de decisiones.</li>
#     <li><ins><strong>Evita colores brillantes o tipografías difíciles de leer:</strong></ins> La estética de la presentación debe ayudar a que el mensaje se entienda, no dificultarlo.</li>
#     <li><ins><strong>No uses transiciones o animaciones excesivas:</strong></ins> Las transiciones deben ser sutiles y no desviar la atención del mensaje principal.</li>
#   </div>
# </div>
#
# ---

# %% [markdown]
# ### **5. Diseño de presentaciones - Tips and Tricks (15 minutos)**
#
# **UTILIZALO EN TU PROYECTO FINAL**
#
# #### **Gráficas recomendadas para presentaciones ejecutivas**
#
# - Gráficas de barras
#   - **Uso:** Comparar categorías o mostrar cambios a lo largo del tiempo.
#   - **Utilidad:** Son simples, eficaces y facilitan la comparación.
#   - **Ejemplo:** Comparar ventas de productos o rendimiento de sucursales.
#
# - Gráficas de líneas
#   - **Uso:** Mostrar la evolución de un dato a lo largo del tiempo.
#   - **Utilidad:** Ideales para visualizar tendencias.
#   - **Ejemplo:** Evolución de ventas mes a mes.
#
# - Gráficas circulares (de pastel)
#   - **Uso:** Mostrar la distribución de un todo entre varias categorías.
#   - **Utilidad:** Representan cómo se dividen las partes de un todo.
#   - **Ejemplo:** Participación de mercado de competidores.
#
# - Gráficas de área
#   - **Uso:** Mostrar el cambio de un valor a lo largo del tiempo, destacando magnitudes.
#   - **Utilidad:** Visualiza la suma de varias series.
#   - **Ejemplo:** Comparación de ingresos por línea de productos.
#
# - Tablas con resúmenes visuales
#   - **Uso:** Resumir datos y facilitar la comparación visual rápida.
#   - **Utilidad:** Mejoran la legibilidad con colores o íconos.
#   - **Ejemplo:** Datos financieros trimestrales con indicadores visuales.
#
# - Gráficas de dispersión
#   - **Uso:** Mostrar la relación entre dos variables.
#   - **Utilidad:** Ayuda a observar correlaciones y tendencias.
#   - **Ejemplo:** Relación entre inversión en marketing y aumento de ventas.
#
# #### **Gráficas a evitar**
#
# - Gráficas de barras 3D
#   - **Por qué evitarlas:** Son difíciles de leer y pueden distorsionar la percepción.
#   - **Alternativa:** Usa barras 2D simples.
#
# - Gráficas circulares con demasiadas categorías
#   - **Por qué evitarlas:** Son confusas con demasiados segmentos.
#   - **Alternativa:** Usa barras o tablas.
#
# - Gráficas de radar
#   - **Por qué evitarlas:** Son complicadas de leer y difíciles de interpretar.
#   - **Alternativa:** Usa tablas comparativas o barras.
#
# - Gráficas de líneas con demasiadas series
#   - **Por qué evitarlas:** Se sobrecargan y dificultan la lectura.
#   - **Alternativa:** Limita las series a 3-4.
#
# - Gráficas de dispersión sin etiquetas o puntos pequeños
#   - **Por qué evitarlas:** Son ilegibles sin etiquetas o puntos claros.
#   - **Alternativa:** Asegúrate de etiquetar y ajustar el tamaño de los puntos.
#
# - Gráficas con escalas no uniformes
#   - **Por qué evitarlas:** Pueden dar una percepción incorrecta de los datos.
#   - **Alternativa:** Usa escalas uniformes y claras.
#
# #### **Uso de Colores**
#
# - **Paleta de Colores Coherente:**
#   - **Limita la paleta de colores:** No utilices más de 3-4 colores principales en toda la presentación. Demasiados colores pueden generar confusión y distraer la atención de la audiencia.
#   - **Usa los colores de la marca:** Si la presentación es para una empresa o institución, utiliza los colores corporativos para mantener la consistencia visual. Esto también fortalece la identidad de la marca.
#   - **Colores neutrales para el fondo:** Colores como el blanco, gris claro o tonos suaves de azul son ideales para el fondo. Evita colores brillantes o saturados que puedan hacer que el texto sea difícil de leer.
#
# - **Contrastes:**
#   - **Contraste alto para la legibilidad:** Asegúrate de que el contraste entre el fondo y el texto sea suficiente. Por ejemplo, texto oscuro sobre fondo claro o texto blanco sobre fondo oscuro.
#   - **Evita colores similares para texto y fondo:** No uses un fondo azul con texto azul claro, ya que esto dificultará la lectura.
#
# - **Psicología del Color:**
#   - **Azul:** Representa profesionalismo, confianza y tranquilidad. Es ideal para negocios y presentaciones ejecutivas.
#   - **Rojo:** Llama la atención y puede usarse para destacar puntos importantes o alertas. Úsalo con moderación, ya que es un color intenso.
#   - **Verde:** Asociado con el crecimiento, la calma y el éxito. Puede usarse para resaltar datos positivos.
#   - **Amarillo:** Energético, pero debe usarse con cautela, ya que puede ser demasiado brillante y cansar a la vista si se usa en exceso.
#   - **Negro o gris oscuro:** Son excelentes para texto y gráficos, proporcionando un aspecto limpio y serio.
#
# ---

# %% [markdown]
# #### **6: Conclusión y Reflexión Final (5 minutos)**
# - La importancia de la claridad y la concisión en las presentaciones ejecutivas.
# - Cómo estructurar una presentación ejecutiva efectiva.
# - El poder del storytelling para hacer las presentaciones más atractivas y persuasivas.
# - Consejos prácticos para mejorar la efectividad de las presentaciones.
# ---

# %% [markdown]
# #### **Reporte de Laboratorio**
#
# ##### 1. Entregar en un archivo *Markdown*:
# - La importancia de la identificación de la audiencia (Tema 2 de la clase).
# - Desarrollo del caso práctico: Tipos de audiencia (de la clase)
# - El reporte debe incluir la respuesta para cada tipo de audiencia (C-level, Director, Gerente):
#   - **Intereses clave:**
#   - **Datos relevantes a presentar:**
#   - **Formato de presentación:**
#   - **Visualización (opcional):**
#
# ##### 2. Explicaciones:
# - Al final del archivo *Markdown*, incluye la siguiente pregunta y su respuesta:
#   - **¿Por qué es importante identificar el tipo de audiencia antes de realizar una presentación?**
#
# **El archivo Markdown debe contener todos los puntos descritos anteriormente.**
