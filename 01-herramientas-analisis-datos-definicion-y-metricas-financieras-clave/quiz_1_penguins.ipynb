# %% [markdown]
# # Quiz Práctico – Penguins Dataset
# **Duración estimada:** 15 minutos

# %% [markdown]
# **Instrucciones:**
# Completa las celdas que se indican con el código necesario.

# %%
import seaborn as sns
import pandas as pd

# Cargar dataset Penguins
penguins = sns.load_dataset("penguins")
penguins.head()

# %% [markdown]
# ## Pregunta 1: Limpieza de datos
#
# 1. ¿Cuántos valores nulos tiene la columna `sex`?
# 2. Elimina todas las filas donde haya nulos.
# 3. Detecta y elimina outliers en la columna `body_mass_g` usando el método IQR.
#    - Outliers: valores < Q1 - 2*IQR o > Q3 + 2*IQR
# 4. Reporta:
#    - Número de filas original.
#    - Número de filas después de eliminar nulos y outliers.

# %%
# === TU CÓDIGO AQUÍ ===

# %% [markdown]
# ## Pregunta 2: Probabilidad de supervivencia
#
# Usando el DataFrame limpio (sin nulos ni outliers de `body_mass_g`):
#
# 1. Calcula el promedio y desviación estandar de la masa corporal (`body_mass_g`) agrupando por:
#    - Sexo (`sex`)
#    - Especie (`species`)
#    - Isla (`island`)
# 2. Reporta una tabla con la información cada combinación y dime que encuentras relevante.

# %%
# === TU CÓDIGO AQUÍ ===

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Carlos Kelly
# </footer>
