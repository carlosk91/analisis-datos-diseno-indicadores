# %% [markdown]
# # Quiz Práctico – Titanic Dataset
# **Duración estimada:** 15 minutos

# %% [markdown]
# **Instrucciones:**
# Completa las celdas que se indican con el código necesario.

# %%
import seaborn as sns
import pandas as pd

# Cargar dataset Titanic
titanic = sns.load_dataset("titanic")
titanic.head()

# %% [markdown]
# ## Pregunta 1: Limpieza de datos
#
# 1. ¿Cuántos valores nulos tiene la columna `age`?
# 2. Elimina todas las filas donde `age` sea nulo.
# 3. Detecta y elimina outliers en la columna `fare` usando el método IQR.
#    - Outliers: valores < Q1 - 1.5*IQR o > Q3 + 1.5*IQR
# 4. Reporta:
#    - Número de filas original.
#    - Número de filas después de eliminar nulos y outliers.

# %%
# === TU CÓDIGO AQUÍ ===

# %% [markdown]
# ## Pregunta 2: Probabilidad de supervivencia
#
# Usando el DataFrame limpio (sin nulos ni outliers en `age` y `fare`):
#
# 1. Calcula la probabilidad de supervivencia agrupando por:
#    - Sexo (`sex`)
#    - Clase del pasajero (`class`)
# 2. Reporta una tabla con la proporción de sobrevivientes en cada combinación.

# %%
# === TU CÓDIGO AQUÍ ===

# %% [markdown]
# Ejemplo esperado (los valores exactos pueden variar):
#
# | sex    | class   | probabilidad_supervivencia |
# |--------|---------|-----------------------------|
# | female | First   | 0.95                        |
# | female | Second  | 0.90                        |
# | male   | Third   | 0.15                        |

# %% [markdown]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#808080; background:#fff;">
# Created with Jupyter by Carlos Kelly
# </footer>
